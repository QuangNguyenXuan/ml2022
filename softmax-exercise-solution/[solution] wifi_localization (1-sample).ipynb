# %% [markdown]
# # 0. Tải bộ dữ liệu wifi_localization
# (**Lưu ý:** nếu không tải được do bị giới hạn số lượt tải, các bạn hãy tải thủ công lên drive và copy vào colab)

# %%
# https://drive.google.com/file/d/1eCqW1U0djlHxREQETL4gsYC3pE-Ngihx/view?usp=share_link
# !gdown --id 1eCqW1U0djlHxREQETL4gsYC3pE-Ngihx
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1eCqW1U0djlHxREQETL4gsYC3pE-Ngihx
# To: /content/wifi_localization.zip
# 100% 14.1k/14.1k [00:00<00:00, 32.5MB/s]

# %%
# !unzip 'wifi_localization.zip'
# Out:
# Archive:  wifi_localization.zip
#   inflating: wifi_localization.csv

# %% [markdown]
# # 1. Tiền xử lý dữ liệu

# %% [markdown]
# ## 1.1. Đọc dữ liệu

# %%
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm 

# Khai báo đường dẫn đến file dataset
dataset_path = "./wifi_localization.csv"
## Đọc dữ liệu file .csv sử dụng np.genfromtxt()
# Đọc dataset
dataset = np.genfromtxt(dataset_path, # Đường dẫn dataset
                        delimiter=",", # Kí tự ngăn cách giữa các cột
                        skip_header=1, # Bỏ qua hàng đầu tiên (chứa tên của cột)
                        dtype=None, # dtype=None sẽ ép hàm genfromtxt phải tìm kiểu dữ liệu của từng cột một cách tuần tự
                        encoding=None) # Tắt tính năng mã hóa dữ liệu sang bytes

# %%
n_samples_glob = dataset.shape[0] # Đọc số lượng mẫu dữ liệu trong dataset (bằng số hàng trong file csv)
n_classes_glob = len(np.unique(dataset[:, -1])) # Đọc số lượng lớp đối tượng dự đoán trong dataset (bằng số lượng giá trị duy nhất của cột cuối cùng trong file .csv)
n_features_glob = dataset.shape[1] - 1 # Đọc số lượng đặc trưng của bộ dữ liệu (bằng số cột trừ cột cuối cùng trong file .csv)
print('Số lượng mẫu dữ liệu (samples): ', n_samples_glob)
print('Số lượng đặc trưng (features): ', n_features_glob)
print('Số lượng lớp đối tượng (classes): ', n_classes_glob)
# Out:
# Số lượng mẫu dữ liệu (samples):  2000
# Số lượng đặc trưng (features):  7
# Số lượng lớp đối tượng (classes):  4

# %% [markdown]
# ## 1.2. Trộn dữ liệu, tách independent/dependent variable, thêm bias, one hot encoding label, chuẩn hóa dữ liệu

# %%
# Trộn (shuffle) dữ liệu
np.random.seed(1) # Cố định kết quả random 
dataset = np.random.permutation(dataset)
# Tách independent varaible và depedent variable thành 2 biến X, y
X, y_idx = dataset[:, :-1].astype(np.float64), dataset[:, -1].astype(np.int32)
# One hot encoding label
y = np.array([np.zeros(n_classes_glob) for _ in range(y_idx.shape[0])])
y[np.arange(len(y_idx)), y_idx] = 1
# Chuẩn hóa dữ liệu bằng phương pháp min-max normalization
X_min = np.min(X, axis=0)
X_max = np.max(X, axis=0)
X = (X - X_min) / (X_max - X_min)
# Tạo ma trận 1 (tượng trưng cho bias của mỗi sample)
bias = np.ones((X.shape[0], 1))
# Thêm bias vào X
X = np.hstack((bias, X))

# %% [markdown]
# ## 1.3. Chia tập Train/Val/Test

# %%
# Khai báo tỉ lệ kích thước của tập train/val/test (không nhất thiết khai báo cho test)
TRAIN_SIZE = 0.7
VAL_SIZE = 0.2

# Tính chỉ mục kết thúc của train, test
TRAIN_IDX_END = int(TRAIN_SIZE * dataset.shape[0])
VAL_IDX_END = int(TRAIN_IDX_END + (VAL_SIZE * dataset.shape[0]))

# Chia train/val/test sử dụng kĩ thuật indexing
X_train, y_train = X[:TRAIN_IDX_END], y[:TRAIN_IDX_END]
X_val, y_val = X[TRAIN_IDX_END:VAL_IDX_END], y[TRAIN_IDX_END:VAL_IDX_END]
X_test, y_test = X[VAL_IDX_END:], y[VAL_IDX_END:]

# %% [markdown]
# # 2. Xây dựng model

# %% [markdown]
# ## 2.1. Khai báo hàm tính softmax

# %%
# Xây dựng hàm dự đoán của model dùng softmax
def softmax(z):
  exp_z = np.exp(z)

  return exp_z / exp_z.sum(axis=0)

# %% [markdown]
# ## 2.2. Khai báo hàm dự đoán

# %%
# Xây dựng hàm dự đoán sử dụng softmax
def predict(X, theta):
  z = theta.T.dot(X) # Tính tích vô hướng
  y_hat = softmax(z) # Tính softmax

  return y_hat

# %% [markdown]
# ## 2.3. Khai báo hàm tính loss (cross entropy)

# %%
# Xây dựng hàm loss cross entropy
def loss(y, y_hat):

  return -np.log(y.T.dot(y_hat))

# %% [markdown]
# ## 2.4. Khai báo hàm tính gradient

# %%
# Xây dựng hàm tính gradient
def gradient(X, y, y_hat):

  return X.dot((y_hat - y).T)

# %% [markdown]
# ## 2.5. Khai báo hàm đánh giá

# %%
# Xây dựng hàm đánh giá
def evaluate(X_test, y_test, theta):
  accs = []
  losses = []
  n_samples = X_test.shape[0]
  n_features = X_test.shape[1]
  n_classes = np.unique(y_test, axis=0).shape[0]
  for i in range(n_samples):
    X_i = X_test[i]
    y_i = y_test[i]

    X_i = X_i.reshape((n_features, 1))
    y_i = y_i.reshape((n_classes, 1))

    y_hat = predict(X_i, theta) # Dự đoán trên mẫu dữ liệu tập test
    test_loss = loss(y_i, y_hat)[0][0] # Tính loss giữa y_hat và y_test
    losses.append(test_loss)
    test_acc = (np.argmax(y_hat) == np.argmax(y_i)) # Tính accuracy giữa y_hat và y_test
    accs.append(test_acc)
  
  return sum(losses) / len(losses), sum(accs) / len(accs)

# %% [markdown]
# ## 2.6. Khai báo hàm training

# %%
# Xây dựng hàm training
def fit(X_train, y_train, theta, EPOCHS=10, LR=1e-4, is_visualize=False):
  train_losses = []
  n_samples = X_train.shape[0]
  n_features = X_train.shape[1]
  n_classes = np.unique(y_train, axis=0).shape[0]
  for epoch in range(EPOCHS):
    progress_bar = tqdm(range(n_samples), desc=f"EPOCH {epoch}", position=0) # Tạo thanh progress thể hiện tiến độ training
    for i in progress_bar:
      # Đọc bộ mẫu dữ liệu tại batch i
      X_i = X_train[i]
      y_i = y_train[i]

      X_i = X_i.reshape((n_features, 1))
      y_i = y_i.reshape((n_classes, 1))

      # Dự đoán mẫu dữ liệu Xi
      y_hat = predict(X_i, theta)

      # Tính train loss, train accuracy
      train_loss = loss(y_i, y_hat)[0][0]
      train_losses.append(train_loss)

      # Tính gradient
      grad = gradient(X_i, y_i, y_hat)

      # Cập nhật trọng số
      theta = theta - LR * grad

      progress_bar.set_postfix({"Train Loss": train_loss}) # Thêm thông tin train loss vừa tính được vào thanh progress

  print("\nTRAINING COMPLETE")

  if is_visualize: # Plot đồ thị train loss nếu is_visualize = True
    plt.plot(train_losses, color='green')
    plt.title("Train loss over batch")
    plt.show()

  return theta

# %% [markdown]
# # 3. Huấn luyện model

# %%
# Khởi tạo bộ trọng số theta ngẫu nhiên (theo phân phối đồng nhất)
np.random.seed(1) # Cố định kết quả random 
theta = np.random.uniform(size=(X_train.shape[1], np.unique(y_train, axis=0).shape[0]))

# %%
# Khai báo các siêu tham số (hyperparameters) và huấn luyện mô hình
EPOCHS = 100
LR = 1e-3
theta = fit(X_train, y_train, theta, EPOCHS, LR, is_visualize=True)
# Out:
# EPOCH 0: 100%|██████████| 1400/1400 [00:03<00:00, 404.39it/s, Train Loss=2.06]
# EPOCH 1: 100%|██████████| 1400/1400 [00:05<00:00, 251.37it/s, Train Loss=1.66]
# EPOCH 2: 100%|██████████| 1400/1400 [00:06<00:00, 231.72it/s, Train Loss=1.48]
# EPOCH 3: 100%|██████████| 1400/1400 [00:05<00:00, 251.11it/s, Train Loss=1.4]
# EPOCH 4: 100%|██████████| 1400/1400 [00:03<00:00, 420.36it/s, Train Loss=1.37]
# EPOCH 5: 100%|██████████| 1400/1400 [00:03<00:00, 415.11it/s, Train Loss=1.36]
# EPOCH 6: 100%|██████████| 1400/1400 [00:03<00:00, 386.79it/s, Train Loss=1.35]
# EPOCH 7: 100%|██████████| 1400/1400 [00:03<00:00, 389.19it/s, Train Loss=1.34]
# EPOCH 8: 100%|██████████| 1400/1400 [00:03<00:00, 382.10it/s, Train Loss=1.33]
# EPOCH 9: 100%|██████████| 1400/1400 [00:03<00:00, 391.97it/s, Train Loss=1.32]
# EPOCH 10: 100%|██████████| 1400/1400 [00:03<00:00, 434.97it/s, Train Loss=1.32]
# EPOCH 11: 100%|██████████| 1400/1400 [00:03<00:00, 456.34it/s, Train Loss=1.31]
# EPOCH 12: 100%|██████████| 1400/1400 [00:03<00:00, 458.20it/s, Train Loss=1.3]
# EPOCH 13: 100%|██████████| 1400/1400 [00:03<00:00, 401.16it/s, Train Loss=1.29]
# EPOCH 14: 100%|██████████| 1400/1400 [00:02<00:00, 482.39it/s, Train Loss=1.28]
# EPOCH 15: 100%|██████████| 1400/1400 [00:03<00:00, 398.59it/s, Train Loss=1.28]
# EPOCH 16: 100%|██████████| 1400/1400 [00:03<00:00, 432.10it/s, Train Loss=1.27]
# EPOCH 17: 100%|██████████| 1400/1400 [00:03<00:00, 463.14it/s, Train Loss=1.26]
# EPOCH 18: 100%|██████████| 1400/1400 [00:03<00:00, 426.58it/s, Train Loss=1.25]
# EPOCH 19: 100%|██████████| 1400/1400 [00:03<00:00, 414.79it/s, Train Loss=1.24]
# EPOCH 20: 100%|██████████| 1400/1400 [00:03<00:00, 456.25it/s, Train Loss=1.24]
# EPOCH 21: 100%|██████████| 1400/1400 [00:03<00:00, 448.84it/s, Train Loss=1.23]
# EPOCH 22: 100%|██████████| 1400/1400 [00:02<00:00, 472.22it/s, Train Loss=1.22]
# EPOCH 23: 100%|██████████| 1400/1400 [00:02<00:00, 483.99it/s, Train Loss=1.21]
# EPOCH 24: 100%|██████████| 1400/1400 [00:03<00:00, 407.71it/s, Train Loss=1.2]
# EPOCH 25: 100%|██████████| 1400/1400 [00:04<00:00, 341.52it/s, Train Loss=1.2]
# EPOCH 26: 100%|██████████| 1400/1400 [00:03<00:00, 374.01it/s, Train Loss=1.19]
# EPOCH 27: 100%|██████████| 1400/1400 [00:03<00:00, 430.57it/s, Train Loss=1.18]
# EPOCH 28: 100%|██████████| 1400/1400 [00:03<00:00, 414.83it/s, Train Loss=1.17]
# EPOCH 29: 100%|██████████| 1400/1400 [00:03<00:00, 453.13it/s, Train Loss=1.17]
# EPOCH 30: 100%|██████████| 1400/1400 [00:02<00:00, 520.82it/s, Train Loss=1.16]
# EPOCH 31: 100%|██████████| 1400/1400 [00:02<00:00, 468.25it/s, Train Loss=1.15]
# EPOCH 33: 100%|██████████| 1400/1400 [00:02<00:00, 530.36it/s, Train Loss=1.14]
# EPOCH 34: 100%|██████████| 1400/1400 [00:02<00:00, 481.55it/s, Train Loss=1.13]
# EPOCH 35: 100%|██████████| 1400/1400 [00:02<00:00, 468.63it/s, Train Loss=1.12]
# EPOCH 38: 100%|██████████| 1400/1400 [00:03<00:00, 418.76it/s, Train Loss=1.1]
# EPOCH 39: 100%|██████████| 1400/1400 [00:02<00:00, 517.41it/s, Train Loss=1.09]
# EPOCH 40: 100%|██████████| 1400/1400 [00:02<00:00, 486.47it/s, Train Loss=1.09]
# EPOCH 41: 100%|██████████| 1400/1400 [00:02<00:00, 473.54it/s, Train Loss=1.08]
# EPOCH 42: 100%|██████████| 1400/1400 [00:02<00:00, 514.74it/s, Train Loss=1.07]
# EPOCH 43: 100%|██████████| 1400/1400 [00:02<00:00, 472.27it/s, Train Loss=1.07]
# EPOCH 44: 100%|██████████| 1400/1400 [00:02<00:00, 469.24it/s, Train Loss=1.06]
# EPOCH 45: 100%|██████████| 1400/1400 [00:02<00:00, 533.78it/s, Train Loss=1.05]
# EPOCH 46: 100%|██████████| 1400/1400 [00:02<00:00, 483.96it/s, Train Loss=1.05]
# EPOCH 47: 100%|██████████| 1400/1400 [00:02<00:00, 470.18it/s, Train Loss=1.04]
# EPOCH 48: 100%|██████████| 1400/1400 [00:02<00:00, 529.57it/s, Train Loss=1.03]
# EPOCH 49: 100%|██████████| 1400/1400 [00:02<00:00, 476.67it/s, Train Loss=1.03]
# EPOCH 50: 100%|██████████| 1400/1400 [00:02<00:00, 485.67it/s, Train Loss=1.02]
# EPOCH 51: 100%|██████████| 1400/1400 [00:02<00:00, 528.88it/s, Train Loss=1.02]
# EPOCH 52: 100%|██████████| 1400/1400 [00:02<00:00, 487.78it/s, Train Loss=1.01]
# EPOCH 53: 100%|██████████| 1400/1400 [00:02<00:00, 488.22it/s, Train Loss=1]
# EPOCH 54: 100%|██████████| 1400/1400 [00:02<00:00, 500.46it/s, Train Loss=0.998]
# EPOCH 55: 100%|██████████| 1400/1400 [00:02<00:00, 536.14it/s, Train Loss=0.992]
# EPOCH 56: 100%|██████████| 1400/1400 [00:02<00:00, 476.65it/s, Train Loss=0.987]
# EPOCH 57: 100%|██████████| 1400/1400 [00:02<00:00, 481.58it/s, Train Loss=0.981]
# EPOCH 58: 100%|██████████| 1400/1400 [00:02<00:00, 532.22it/s, Train Loss=0.976]
# EPOCH 59: 100%|██████████| 1400/1400 [00:02<00:00, 488.14it/s, Train Loss=0.97]
# EPOCH 60: 100%|██████████| 1400/1400 [00:03<00:00, 465.33it/s, Train Loss=0.965]
# EPOCH 61: 100%|██████████| 1400/1400 [00:02<00:00, 499.20it/s, Train Loss=0.959]
# EPOCH 62: 100%|██████████| 1400/1400 [00:03<00:00, 453.98it/s, Train Loss=0.954]
# EPOCH 63: 100%|██████████| 1400/1400 [00:03<00:00, 453.06it/s, Train Loss=0.948]
# EPOCH 64: 100%|██████████| 1400/1400 [00:02<00:00, 479.48it/s, Train Loss=0.943]
# EPOCH 68: 100%|██████████| 1400/1400 [00:03<00:00, 447.64it/s, Train Loss=0.923]
# EPOCH 69: 100%|██████████| 1400/1400 [00:03<00:00, 461.03it/s, Train Loss=0.918]
# EPOCH 70: 100%|██████████| 1400/1400 [00:02<00:00, 500.48it/s, Train Loss=0.913]
# EPOCH 71: 100%|██████████| 1400/1400 [00:03<00:00, 436.00it/s, Train Loss=0.908]
# EPOCH 72: 100%|██████████| 1400/1400 [00:03<00:00, 420.96it/s, Train Loss=0.903]
# EPOCH 76: 100%|██████████| 1400/1400 [00:03<00:00, 455.37it/s, Train Loss=0.885]
# EPOCH 77: 100%|██████████| 1400/1400 [00:02<00:00, 490.95it/s, Train Loss=0.88]
# EPOCH 78: 100%|██████████| 1400/1400 [00:03<00:00, 440.63it/s, Train Loss=0.876]
# EPOCH 79: 100%|██████████| 1400/1400 [00:03<00:00, 440.16it/s, Train Loss=0.871]
# EPOCH 84: 100%|██████████| 1400/1400 [00:02<00:00, 498.15it/s, Train Loss=0.849]
# EPOCH 85: 100%|██████████| 1400/1400 [00:02<00:00, 491.24it/s, Train Loss=0.845]
# EPOCH 86: 100%|██████████| 1400/1400 [00:02<00:00, 528.05it/s, Train Loss=0.841]
# EPOCH 89: 100%|██████████| 1400/1400 [00:02<00:00, 488.31it/s, Train Loss=0.829]
# EPOCH 90: 100%|██████████| 1400/1400 [00:03<00:00, 452.77it/s, Train Loss=0.825]
# EPOCH 91: 100%|██████████| 1400/1400 [00:03<00:00, 445.16it/s, Train Loss=0.821]
# EPOCH 92: 100%|██████████| 1400/1400 [00:02<00:00, 541.28it/s, Train Loss=0.817]
# EPOCH 93: 100%|██████████| 1400/1400 [00:02<00:00, 500.30it/s, Train Loss=0.813]
# EPOCH 98:  94%|█████████▎| 1312/1400 [00:02<00:00, 529.79it/s, Train Loss=0.794]
# TRAINING COMPLETE

# %% [markdown]
# # 4. Đánh giá model

# %%
# Đánh giá trên tập validation
val_loss, val_acc = evaluate(X_val, y_val, theta)
print("Validation loss: ", np.round(val_loss, 3))
print("Validation accuracy: ", np.round(val_acc, 3))

# Đánh giá trên tập test
test_loss, test_acc = evaluate(X_test, y_test, theta)
print("Test loss: ", np.round(test_loss, 3))
print("Test accuracy: ", np.round(test_acc, 3))
# Out:
# Validation loss:  0.478
# Validation accuracy:  0.97
# Test loss:  0.459
# Test accuracy:  0.975
